# %%
import numpy as np
import matplotlib.pyplot as plt

print("NumPy version:", np.__version__)

plt.figure()
plt.plot([1, 2, 3], [1, 4, 9], marker="o")
plt.title("Test plot")
plt.grid(True)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# NumPy version: 1.26.4

# %%
import pandas as pd

scope_df = pd.read_excel("HM_Scope_Emissions_Clean.xlsx")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
# ----> 3 scope_df = pd.read_excel("HM_Scope_Emissions_Clean.xlsx")
#
# File ~\hmplot\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
# ...

# %%
import os
os.chdir(r"C:\Users\sreel\OneDrive\Documents\python")
os.listdir()
# Out:
# ['HM-Group-Annual-and-sustainability-report-2024.pdf',
#  'HM_Scope_Emissions_Clean.xlsx',
#  'table1.csv']

# %%
import pandas as pd

scope_df = pd.read_excel("HM_Scope_Emissions_Clean.xlsx")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~\hmplot\lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~\anaconda3\lib\importlib\__init__.py:127, in import_module(name, package)
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1030, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:984, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
import PyPDF2

pdf_file = open("HM-Group-Annual-and-sustainability-report-2024.pdf", "rb")
pdf_reader = PyPDF2.PdfReader(pdf_file)

all_text = ""

for page in pdf_reader.pages:
    text = page.extract_text()
    if text:
        all_text += text

print(all_text[:1500])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import PyPDF2
#       3 pdf_file = open("HM-Group-Annual-and-sustainability-report-2024.pdf", "rb")
#       4 pdf_reader = PyPDF2.PdfReader(pdf_file)
#
# ModuleNotFoundError: No module named 'PyPDF2'

# %%
# !pip install PyPDF2

# %%
import PyPDF2

pdf_file = open("HM-Group-Annual-and-sustainability-report-2024.pdf", "rb")
pdf_reader = PyPDF2.PdfReader(pdf_file)

all_text = ""

for page in pdf_reader.pages:
    text = page.extract_text()
    if text:
        all_text += text

print(all_text[:1500])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import PyPDF2
#       3 pdf_file = open("HM-Group-Annual-and-sustainability-report-2024.pdf", "rb")
#       4 pdf_reader = PyPDF2.PdfReader(pdf_file)
#
# ModuleNotFoundError: No module named 'PyPDF2'

# %%
import PyPDF2

pdf_file = open("HM-Group-Annual-and-sustainability-report-2024.pdf", "rb")
pdf_reader = PyPDF2.PdfReader(pdf_file)

all_text = ""

for page in pdf_reader.pages:
    text = page.extract_text()
    if text:
        all_text += text

print(all_text[:1500])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import PyPDF2
#       3 pdf_file = open("HM-Group-Annual-and-sustainability-report-2024.pdf", "rb")
#       4 pdf_reader = PyPDF2.PdfReader(pdf_file)
#
# ModuleNotFoundError: No module named 'PyPDF2'

# %%
import PyPDF2

pdf_file = open("HM-Group-Annual-and-sustainability-report-2024.pdf", "rb")
pdf_reader = PyPDF2.PdfReader(pdf_file)

all_text = ""

for page in pdf_reader.pages:
    text = page.extract_text()
    if text:
        all_text += text

print(all_text[:1500])
# Out:
# H&M GROUP
# ANNUAL & SUST AINABILITY REPORT2024H&M Group is not just a family of brands.
# It’s som
# ething bigger. It’s an idea that goes
# all the way back to our founder. In short,
# it’s about unlocking the positive power of fashion for everyone. About the report
# This document is H&M Group’s annual and
# sustain  ability report detailing our financial and
# non-financial performance in the year from
# 1 December 2023 to 30 November 2024 (the
# 2024 financial year). It in   cl udes comments
# from our CEO and a description of the  bu siness,
# followed by our statutory annual report.
# Our annual and sustainability report complies
# with the applicable Swedish and EU legislation and the International Financial Reporting Standards (IFRS) adopted by the EU, and is
#  prepared in accordance with the Swedish
# Annual Accounts Act.
# We complement our annual and sustainability
# ...

# %%
def extract_scope(keyword, label):
    df = scope_df[
        scope_df.iloc[:, 0].str.contains(keyword, case=False, na=False)
    ][["2019_baseline", "2022", "2023", "2024"]].T
    df.columns = [label]
    return df

scope1 = extract_scope("scope 1", "Scope 1")
scope2 = extract_scope("scope 2", "Scope 2")
scope3 = extract_scope("scope 3", "Scope 3")

trend = scope1.join(scope2).join(scope3)

plt.figure()
for col in trend.columns:
    plt.plot(trend.index, trend[col], marker='o', label=col)

plt.xlabel("Year")
plt.ylabel("Emissions (tonnes CO₂e)")
plt.title("GHG Emissions Trend (Scope 1, 2 & 3)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 8
#       5     df.columns = [label]
#       6     return df
# ----> 8 scope1 = extract_scope("scope 1", "Scope 1")
#       9 scope2 = extract_scope("scope 2", "Scope 2")
#      10 scope3 = extract_scope("scope 3", "Scope 3")
#
# Cell In[11], line 2, in extract_scope(keyword, label)
#       1 def extract_scope(keyword, label):
# ----> 2     df = scope_df[
#       3         scope_df.iloc[:, 0].str.contains(keyword, case=False, na=False)
#       4     ][["2019_baseline", "2022", "2023", "2024"]].T
#       5     df.columns = [label]
#       6     return df
#
# NameError: name 'scope_df' is not defined

# %%
scope_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 scope_df
#
# NameError: name 'scope_df' is not defined

# %%
import pandas as pd

# Keep rows that mention scope
scope_df = df[
    df.iloc[:, 0]
    .astype(str)
    .str.lower()
    .str.contains("scope")
]

scope_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 4
#       1 import pandas as pd
#       3 # Keep rows that mention scope
# ----> 4 scope_df = df[
#       5     df.iloc[:, 0]
#       6     .astype(str)
#       7     .str.lower()
#       8     .str.contains("scope")
#       9 ]
#      11 scope_df
#
# NameError: name 'df' is not defined

# %%
scope_tables = []

for i, table in enumerate(tables):
    df = table.df
    text = " ".join(df.astype(str).values.flatten()).lower()
    
    if "scope 1" in text or "scope 2" in text or "scope 3" in text:
        scope_tables.append(i)
        print(f"\n✅ Scope data found in Table {i}")
        display(df.head(15))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 scope_tables = []
# ----> 3 for i, table in enumerate(tables):
#       4     df = table.df
#       5     text = " ".join(df.astype(str).values.flatten()).lower()
#
# NameError: name 'tables' is not defined

# %%
tables = camelot.read_pdf(
    "HM-Group-Annual-and-sustainability-report-2024.pdf",
    pages="30-36",
    flavor="stream"
)

tables.n
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 tables = camelot.read_pdf(
#       2     "HM-Group-Annual-and-sustainability-report-2024.pdf",
#       3     pages="30-36",
#       4     flavor="stream"
#       5 )
#       7 tables.n
#
# NameError: name 'camelot' is not defined

# %%
import camelot
camelot.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import camelot
#       2 camelot.__version__
#
# ModuleNotFoundError: No module named 'camelot'

# %%
import camelot
tables = camelot.read_pdf("HM-Group-Annual-and-sustainability-report-2024.pdf", pages="all")
tables.n
# Out:
# C:\Users\sreel\hmplot\lib\site-packages\pypdf\_crypt_providers\_cryptography.py:32: CryptographyDeprecationWarning: ARC4 has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.ARC4 and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   from cryptography.hazmat.primitives.ciphers.algorithms import AES, ARC4
# C:\Users\sreel\hmplot\lib\site-packages\camelot\parsers\base.py:124: UserWarning: page-86 is image-based, camelot only works on text-based pages.
#   warnings.warn(
# C:\Users\sreel\hmplot\lib\site-packages\camelot\parsers\base.py:124: UserWarning: page-87 is image-based, camelot only works on text-based pages.
#   warnings.warn(
# 7

# %%
import camelot
camelot.__version__
# Out:
# '1.0.9'

# %%
import PyPDF2

pdf = PyPDF2.PdfReader(open("HM-Group-Annual-and-sustainability-report-2024.pdf", "rb"))

for i, page in enumerate(pdf.pages):
    text = page.extract_text()
    if text and "scope" in text.lower():
        print("Possible emissions page:", i+1)
# Out:
# Possible emissions page: 5
# Possible emissions page: 8
# Possible emissions page: 10
# Possible emissions page: 22
# Possible emissions page: 26
# Possible emissions page: 27
# Possible emissions page: 30
# Possible emissions page: 32
# Possible emissions page: 33
# Possible emissions page: 34
# Possible emissions page: 35
# Possible emissions page: 36
# Possible emissions page: 39
# Possible emissions page: 40
# Possible emissions page: 41
# Possible emissions page: 42
# Possible emissions page: 46
# Possible emissions page: 50
# Possible emissions page: 51
# Possible emissions page: 52
# Possible emissions page: 57
# Possible emissions page: 58
# Possible emissions page: 80

# %%
tables = camelot.read_pdf(
    "HM-Group-Annual-and-sustainability-report-2024.pdf",
    pages="120-123",
    flavor="stream"
)

tables.n
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 tables = camelot.read_pdf(
#       2     "HM-Group-Annual-and-sustainability-report-2024.pdf",
#       3     pages="120-123",
#       4     flavor="stream"
#       5 )
#       7 tables.n
#
# File ~\hmplot\lib\site-packages\camelot\io.py:134, in read_pdf(filepath, pages, password, flavor, suppress_stdout, parallel, layout_kwargs, debug, **kwargs)
#     132 p = PDFHandler(filepath, pages=pages, password=password, debug=debug)
#     133 kwargs = remove_extra(kwargs, flavor=flavor)
# --> 134 tables = p.parse(
#     135     flavor=flavor,
#     136     suppress_stdout=suppress_stdout,
#     137     parallel=parallel,
#     138     layout_kwargs=layout_kwargs,
#     139     **kwargs,
#     140 )
#     141 return tables
#
# ...

# %%
tables = camelot.read_pdf(
    "HM-Group-Annual-and-sustainability-report-2024.pdf",
    pages="30-36",
    flavor="stream"
)

tables.n
# Out:
# C:\Users\sreel\hmplot\lib\site-packages\camelot\parsers\base.py:238: UserWarning: No tables found in table area (742.5984, 106.38519999999997, 1253.6135999999995, 284.23285269461076)
#   cols, rows, v_s, h_s = self._generate_columns_and_rows(bbox, user_cols)
# 15

# %%
scope_tables = []

for i, table in enumerate(tables):
    df = table.df
    text = " ".join(df.astype(str).values.flatten()).lower()
    
    if "scope 1" in text or "scope 2" in text or "scope 3" in text:
        scope_tables.append(i)
        print(f"\n✅ Scope data found in Table {i}")
        display(df.head(15))
# Out:
# ✅ Scope data found in Table 5
#                                                     0  \
# 0                                 Targets and actions
# 1   To reach our ambition and limit global warming...
# 2   related to our GHG emissions and energy consum...
# 3   chain. We continually evaluate our climate tar...
# 4   annual progress, with a dual focus: improving ...
# 5
# 6   reporting of climate data, and our consultatio...
# 7
# 8   such as WWF, Stand.earth, and the United Natio...
# 9
# 10  Climate Change ( UNFCCC). These collaborative ...
# 11
# 12  improvement of our targets and operational str...
# 13
# 14
#
#                                                     1  \
# 0   have set a target to source 100 percent renewa...
# 1   production, from spinning to a finished produc...
# 2   target to completely phase out coal from our g...
# 3   For emissions related to raw material sourcing...
# 4   the share of recycled materials, see pages 73–...
# 5
# 6
# 7
# ...

# %%
import pandas as pd

df = tables[9].df

# Use first row as header
df.columns = df.iloc[0]
df = df[1:]

# Clean formatting
df = df.replace("", pd.NA)
df = df.dropna(how="all")
df.reset_index(drop=True, inplace=True)

df
# Out:
# 0               GHG emission reduction targets1, 2, 3                        \
# 0                                                <NA>       <NA>       <NA>
# 1                                                <NA>       <NA>       <NA>
# 2                                                <NA>       2024       2023
# 3                                                <NA>       <NA>       <NA>
# 4               Total scope 1 emissions (tonnes CO2e)     15,102     15,754
# 5                                                <NA>       <NA>       <NA>
# 6   Total location based scope 2 emissions (tonnes...    364,693    377,573
# 7                                                <NA>       <NA>       <NA>
# 8                                                <NA>       <NA>       <NA>
# 9   Total market based scope 2 emissions (tonnes C...     26,553     39,508
# 10   Total scope 1 and scope 2 market based emissions     41,655     55,262
# ...

# %%
for col in df.columns[1:]:
    df[col] = (
        df[col]
        .astype(str)
        .str.replace(",", "")
        .str.replace(" ", "")
    )
    df[col] = pd.to_numeric(df[col], errors="coerce")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8276\3102276281.py in ?()
#       1 for col in df.columns[1:]:
#       2     df[col] = (
# ----> 3         df[col]
#       4         .astype(str)
#       5         .str.replace(",", "")
#       6         .str.replace(" ", "")
#
# ~\hmplot\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
df
# Out:
# 0               GHG emission reduction targets1, 2, 3                        \
# 0                                                <NA>       <NA>       <NA>
# 1                                                <NA>       <NA>       <NA>
# 2                                                <NA>       2024       2023
# 3                                                <NA>       <NA>       <NA>
# 4               Total scope 1 emissions (tonnes CO2e)     15,102     15,754
# 5                                                <NA>       <NA>       <NA>
# 6   Total location based scope 2 emissions (tonnes...    364,693    377,573
# 7                                                <NA>       <NA>       <NA>
# 8                                                <NA>       <NA>       <NA>
# 9   Total market based scope 2 emissions (tonnes C...     26,553     39,508
# 10   Total scope 1 and scope 2 market based emissions     41,655     55,262
# ...

# %%
df.shape
df.columns
# Out:
# Index(['GHG emission reduction targets1, 2, 3', '', '', '', '', '', '', '', '',
#        '', ''],
#       dtype='object', name=0)

# %%
import pandas as pd

# Keep rows that mention scope
scope_df = df[
    df.iloc[:, 0]
    .astype(str)
    .str.lower()
    .str.contains("scope")
]

scope_df
# Out:
# 0               GHG emission reduction targets1, 2, 3                        \
# 4               Total scope 1 emissions (tonnes CO2e)     15,102     15,754
# 6   Total location based scope 2 emissions (tonnes...    364,693    377,573
# 9   Total market based scope 2 emissions (tonnes C...     26,553     39,508
# 10   Total scope 1 and scope 2 market based emissions     41,655     55,262
# 12    Total scope 3 emissions (tonnes CO2e) under our  6,955,000  6,754,000
# 16  Total scope 3 emissions including use-phase em...  8,729,000  8,413,000
# 20            Total scope 1 emissions intensity value       0.06       0.07
# 22  Total market based scope 2 emissions intensity...       0.11       0.17
# 24            Total scope 3 emissions intensity value       37.2       35.6
# 27  Total scope 3 emissions including use-phase em...       29.7       28.6
#
# 0                                                  \
# 4      18,048      21,564  2030, –56%   –4%  –30%
# ...

# %%
scope_df = scope_df.iloc[:, :5]
scope_df
# Out:
# 0               GHG emission reduction targets1, 2, 3                        \
# 4               Total scope 1 emissions (tonnes CO2e)     15,102     15,754
# 6   Total location based scope 2 emissions (tonnes...    364,693    377,573
# 9   Total market based scope 2 emissions (tonnes C...     26,553     39,508
# 10   Total scope 1 and scope 2 market based emissions     41,655     55,262
# 12    Total scope 3 emissions (tonnes CO2e) under our  6,955,000  6,754,000
# 16  Total scope 3 emissions including use-phase em...  8,729,000  8,413,000
# 20            Total scope 1 emissions intensity value       0.06       0.07
# 22  Total market based scope 2 emissions intensity...       0.11       0.17
# 24            Total scope 3 emissions intensity value       37.2       35.6
# 27  Total scope 3 emissions including use-phase em...       29.7       28.6
#
# 0
# 4      18,048      21,564
# 6     443,099     658,646
# 9      46,806      48,735
# 10     64,854      70,299
# ...

# %%
scope_df.columns = [
    "Metric",
    "2024",
    "2023",
    "2022",
    "2019_baseline"
]

scope_df
# Out:
#                                                Metric       2024       2023  \
# 4               Total scope 1 emissions (tonnes CO2e)     15,102     15,754
# 6   Total location based scope 2 emissions (tonnes...    364,693    377,573
# 9   Total market based scope 2 emissions (tonnes C...     26,553     39,508
# 10   Total scope 1 and scope 2 market based emissions     41,655     55,262
# 12    Total scope 3 emissions (tonnes CO2e) under our  6,955,000  6,754,000
# 16  Total scope 3 emissions including use-phase em...  8,729,000  8,413,000
# 20            Total scope 1 emissions intensity value       0.06       0.07
# 22  Total market based scope 2 emissions intensity...       0.11       0.17
# 24            Total scope 3 emissions intensity value       37.2       35.6
# 27  Total scope 3 emissions including use-phase em...       29.7       28.6
#
#          2022 2019_baseline
# 4      18,048        21,564
# 6     443,099       658,646
# 9      46,806        48,735
# ...

# %%
for col in ["2024", "2023", "2022", "2019_baseline"]:
    scope_df[col] = scope_df[col].apply(
        lambda x: float(str(x).replace(",", "").replace("–", "").strip())
        if str(x).strip() not in ["", "<NA>"] else None
    )
# Out:
# C:\Users\sreel\AppData\Local\Temp\ipykernel_8276\1636434069.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   scope_df[col] = scope_df[col].apply(

# %%
scope_df
scope_df.dtypes
# Out:
# Metric            object
# 2024             float64
# 2023             float64
# 2022             float64
# 2019_baseline    float64
# dtype: object

# %%
scope_df.to_excel("HM_Scope_Emissions_Clean.xlsx", index=False)

# %%
scope1 = scope_df[
    scope_df.iloc[:, 0].str.contains("scope 1", case=False, na=False)
][["2019_baseline", "2022", "2023", "2024"]].T

scope1.columns = ["Scope 1"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 5
#       1 scope1 = scope_df[
#       2     scope_df.iloc[:, 0].str.contains("scope 1", case=False, na=False)
#       3 ][["2019_baseline", "2022", "2023", "2024"]].T
# ----> 5 scope1.columns = ["Scope 1"]
#
# File ~\hmplot\lib\site-packages\pandas\core\generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
#    6337     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\hmplot\lib\site-packages\pandas\core\generic.py:817, in NDFrame._set_axis(self, axis, labels)
#     812 """
#     813 This is called from the cython code when we set the `index` attribute
# ...

# %%
scope1 = scope_df[
    scope_df.iloc[:, 0].str.contains("scope 1", case=False, na=False)
][["2019_baseline", "2022", "2023", "2024"]].T

scope1.columns = [scope1.columns[0]]  # keep existing name
scope1 = scope1.rename(columns={scope1.columns[0]: "Scope 1"})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 5
#       1 scope1 = scope_df[
#       2     scope_df.iloc[:, 0].str.contains("scope 1", case=False, na=False)
#       3 ][["2019_baseline", "2022", "2023", "2024"]].T
# ----> 5 scope1.columns = [scope1.columns[0]]  # keep existing name
#       6 scope1 = scope1.rename(columns={scope1.columns[0]: "Scope 1"})
#
# File ~\hmplot\lib\site-packages\pandas\core\generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
#    6337     pass
#
# File pandas/_libs/properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\hmplot\lib\site-packages\pandas\core\generic.py:817, in NDFrame._set_axis(self, axis, labels)
#     812 """
# ...

# %%
scope_df.iloc[:, 0]
# Out:
# 4                 Total scope 1 emissions (tonnes CO2e)
# 6     Total location based scope 2 emissions (tonnes...
# 9     Total market based scope 2 emissions (tonnes C...
# 10     Total scope 1 and scope 2 market based emissions
# 12      Total scope 3 emissions (tonnes CO2e) under our
# 16    Total scope 3 emissions including use-phase em...
# 20              Total scope 1 emissions intensity value
# 22    Total market based scope 2 emissions intensity...
# 24              Total scope 3 emissions intensity value
# 27    Total scope 3 emissions including use-phase em...
# Name: Metric, dtype: object

# %%
import matplotlib.pyplot as plt

# pick the row whose Metric text contains "Total scope 1 emissions"
row_scope1 = scope_df[
    scope_df.iloc[:, 0].str.contains("Total scope 1 emissions", case=False, na=False)
].iloc[0]

# select the year columns and rename the index to simple years
scope1 = row_scope1[["2019_baseline", "2022", "2023", "2024"]]
scope1.index = ["2019", "2022", "2023", "2024"]

print(scope1)
# Out:
# 2019    21564.0
# 2022    18048.0
# 2023    15754.0
# 2024    15102.0
# Name: 4, dtype: object

# %%
plt.figure()
plt.plot(scope1.index, scope1.values, marker="o")
plt.xlabel("Year")
plt.ylabel("Emissions (tonnes CO2e)")
plt.title("Total Scope 1 Emissions Trend")
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# helper: get one row by partial metric name
def get_scope_row(text):
    return scope_df[
        scope_df.iloc[:, 0].str.contains(text, case=False, na=False)
    ].iloc[0]

row_s1 = get_scope_row("Total scope 1 emissions")
row_s2 = get_scope_row("Total location based scope 2 emissions")
row_s3 = get_scope_row("Total scope 3 emissions (tonnes CO2e)")

years_cols = ["2019_baseline", "2022", "2023", "2024"]
years = ["2019", "2022", "2023", "2024"]

scope1 = row_s1[years_cols]
scope2 = row_s2[years_cols]
scope3 = row_s3[years_cols]

scope1.index = years
scope2.index = years
scope3.index = years
# Out:
# C:\Users\sreel\AppData\Local\Temp\ipykernel_8276\784241116.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   scope_df.iloc[:, 0].str.contains(text, case=False, na=False)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[38], line 11
#       9 row_s1 = get_scope_row("Total scope 1 emissions")
#      10 row_s2 = get_scope_row("Total location based scope 2 emissions")
# ---> 11 row_s3 = get_scope_row("Total scope 3 emissions (tonnes CO2e)")
#      13 years_cols = ["2019_baseline", "2022", "2023", "2024"]
#      14 years = ["2019", "2022", "2023", "2024"]
#
# Cell In[38], line 5, in get_scope_row(text)
#       4 def get_scope_row(text):
# ----> 5     return scope_df[
#       6         scope_df.iloc[:, 0].str.contains(text, case=False, na=False)
#       7     ].iloc[0]
#
# ...

# %%
def extract_scope(keyword, label):
    df = scope_df[
        scope_df.iloc[:, 0].str.contains(keyword, case=False, na=False)
    ][["2019_baseline", "2022", "2023", "2024"]].T
    df.columns = [label]
    return df

scope1 = extract_scope("scope 1", "Scope 1")
scope2 = extract_scope("scope 2", "Scope 2")
scope3 = extract_scope("scope 3", "Scope 3")

trend = scope1.join(scope2).join(scope3)

plt.figure()
for col in trend.columns:
    plt.plot(trend.index, trend[col], marker='o', label=col)

plt.xlabel("Year")
plt.ylabel("Emissions (tonnes CO₂e)")
plt.title("GHG Emissions Trend (Scope 1, 2 & 3)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 8
#       5     df.columns = [label]
#       6     return df
# ----> 8 scope1 = extract_scope("scope 1", "Scope 1")
#       9 scope2 = extract_scope("scope 2", "Scope 2")
#      10 scope3 = extract_scope("scope 3", "Scope 3")
#
# Cell In[39], line 5, in extract_scope(keyword, label)
#       1 def extract_scope(keyword, label):
#       2     df = scope_df[
#       3         scope_df.iloc[:, 0].str.contains(keyword, case=False, na=False)
#       4     ][["2019_baseline", "2022", "2023", "2024"]].T
# ----> 5     df.columns = [label]
#       6     return df
#
# File ~\hmplot\lib\site-packages\pandas\core\generic.py:6335, in NDFrame.__setattr__(self, name, value)
#    6333 try:
#    6334     object.__getattribute__(self, name)
# -> 6335     return object.__setattr__(self, name, value)
#    6336 except AttributeError:
# ...

# %%
import matplotlib.pyplot as plt

def get_scope_row(text):
    return scope_df[
        scope_df.iloc[:, 0].str.contains(text, case=False, na=False)
    ].iloc[0]

row_s1 = get_scope_row("Total scope 1 emissions")
row_s2 = get_scope_row("Total location based scope 2 emissions")
row_s3 = get_scope_row("Total scope 3 emissions (tonnes CO2e)")

years_cols = ["2019_baseline", "2022", "2023", "2024"]
years = ["2019", "2022", "2023", "2024"]

scope1 = row_s1[years_cols].astype(float)
scope2 = row_s2[years_cols].astype(float)
scope3 = row_s3[years_cols].astype(float)

total_scope123 = scope1 + scope2 + scope3
total_scope123.index = years
# Out:
# C:\Users\sreel\AppData\Local\Temp\ipykernel_8276\2262497958.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   scope_df.iloc[:, 0].str.contains(text, case=False, na=False)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[40], line 10
#       8 row_s1 = get_scope_row("Total scope 1 emissions")
#       9 row_s2 = get_scope_row("Total location based scope 2 emissions")
# ---> 10 row_s3 = get_scope_row("Total scope 3 emissions (tonnes CO2e)")
#      12 years_cols = ["2019_baseline", "2022", "2023", "2024"]
#      13 years = ["2019", "2022", "2023", "2024"]
#
# Cell In[40], line 4, in get_scope_row(text)
#       3 def get_scope_row(text):
# ----> 4     return scope_df[
#       5         scope_df.iloc[:, 0].str.contains(text, case=False, na=False)
#       6     ].iloc[0]
#
# ...

# %%
row_s1 = scope_df[
    scope_df.iloc[:, 0].str.contains("Total scope 1 emissions", case=False, na=False)
].iloc[0]

row_s2 = scope_df[
    scope_df.iloc[:, 0].str.contains("Total location based scope 2 emissions", case=False, na=False)
].iloc[0]

row_s3 = scope_df[
    scope_df.iloc[:, 0].str.contains("Total scope 3 emissions (tonnes CO2e)", case=False, na=False)
].iloc[0]
# Out:
# C:\Users\sreel\AppData\Local\Temp\ipykernel_8276\3091398316.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   scope_df.iloc[:, 0].str.contains("Total scope 3 emissions (tonnes CO2e)", case=False, na=False)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[41], line 9
#       1 row_s1 = scope_df[
#       2     scope_df.iloc[:, 0].str.contains("Total scope 1 emissions", case=False, na=False)
#       3 ].iloc[0]
#       5 row_s2 = scope_df[
#       6     scope_df.iloc[:, 0].str.contains("Total location based scope 2 emissions", case=False, na=False)
#       7 ].iloc[0]
# ----> 9 row_s3 = scope_df[
#      10     scope_df.iloc[:, 0].str.contains("Total scope 3 emissions (tonnes CO2e)", case=False, na=False)
#      11 ].iloc[0]
#
# ...

# %%
scope_rows = scope_df[
    scope_df.iloc[:, 0].str.contains("scope", case=False, na=False)
]
print(scope_rows.iloc[:, 0])
# Out:
# 4                 Total scope 1 emissions (tonnes CO2e)
# 6     Total location based scope 2 emissions (tonnes...
# 9     Total market based scope 2 emissions (tonnes C...
# 10     Total scope 1 and scope 2 market based emissions
# 12      Total scope 3 emissions (tonnes CO2e) under our
# 16    Total scope 3 emissions including use-phase em...
# 20              Total scope 1 emissions intensity value
# 22    Total market based scope 2 emissions intensity...
# 24              Total scope 3 emissions intensity value
# 27    Total scope 3 emissions including use-phase em...
# Name: Metric, dtype: object

# %%
text_s1 = "Total scope 1 emissions (tonnes CO2e)"                # edit if different
text_s2 = "Total location based scope 2 emissions"               # edit if different
text_s3 = "Total scope 3 emissions (tonnes CO2e)"                # edit if different / add 'under our' etc.

s1_df = scope_df[scope_df.iloc[:, 0].str.contains(text_s1, case=False, na=False)]
s2_df = scope_df[scope_df.iloc[:, 0].str.contains(text_s2, case=False, na=False)]
s3_df = scope_df[scope_df.iloc[:, 0].str.contains(text_s3, case=False, na=False)]

print("Scope 1 rows:\n", s1_df)
print("Scope 2 rows:\n", s2_df)
print("Scope 3 rows:\n", s3_df)
# Out:
# Scope 1 rows:
#  Empty DataFrame
# Columns: [Metric, 2024, 2023, 2022, 2019_baseline]
# Index: []
# Scope 2 rows:
#                                                Metric      2024      2023  \
# 6  Total location based scope 2 emissions (tonnes...  364693.0  377573.0
#
#        2022  2019_baseline
# 6  443099.0       658646.0
# Scope 3 rows:
#  Empty DataFrame
# Columns: [Metric, 2024, 2023, 2022, 2019_baseline]
# Index: []
# C:\Users\sreel\AppData\Local\Temp\ipykernel_8276\1198045781.py:5: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   s1_df = scope_df[scope_df.iloc[:, 0].str.contains(text_s1, case=False, na=False)]
# C:\Users\sreel\AppData\Local\Temp\ipykernel_8276\1198045781.py:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
# ...

# %%
import matplotlib.pyplot as plt

years_cols = ["2019_baseline", "2022", "2023", "2024"]
years      = ["2019", "2022", "2023", "2024"]

row_s1 = s1_df.iloc[0][years_cols].astype(float)
row_s2 = s2_df.iloc[0][years_cols].astype(float)
row_s3 = s3_df.iloc[0][years_cols].astype(float)

total_scope123 = row_s1 + row_s2 + row_s3
total_scope123.index = years

plt.figure()
plt.plot(total_scope123.index, total_scope123.values, marker="o", color="purple")
plt.xlabel("Year")
plt.ylabel("Total emissions (tonnes CO2e)")
plt.title("Total Scope 1+2+3 Emissions Trend")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 6
#       3 years_cols = ["2019_baseline", "2022", "2023", "2024"]
#       4 years      = ["2019", "2022", "2023", "2024"]
# ----> 6 row_s1 = s1_df.iloc[0][years_cols].astype(float)
#       7 row_s2 = s2_df.iloc[0][years_cols].astype(float)
#       8 row_s3 = s3_df.iloc[0][years_cols].astype(float)
#
# File ~\hmplot\lib\site-packages\pandas\core\indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\hmplot\lib\site-packages\pandas\core\indexing.py:1753, in _iLocIndexer._getitem_axis(self, key, axis)
#    1750     raise TypeError("Cannot index by location index with a non-integer key")
# ...

# %%
scope_rows = scope_df[
    scope_df.iloc[:, 0].str.contains("scope", case=False, na=False)
]
print(scope_rows[[scope_df.columns[0]]])
# Out:
#                                                Metric
# 4               Total scope 1 emissions (tonnes CO2e)
# 6   Total location based scope 2 emissions (tonnes...
# 9   Total market based scope 2 emissions (tonnes C...
# 10   Total scope 1 and scope 2 market based emissions
# 12    Total scope 3 emissions (tonnes CO2e) under our
# 16  Total scope 3 emissions including use-phase em...
# 20            Total scope 1 emissions intensity value
# 22  Total market based scope 2 emissions intensity...
# 24            Total scope 3 emissions intensity value
# 27  Total scope 3 emissions including use-phase em...

# %%
import matplotlib.pyplot as plt

years_cols = ["2019_baseline", "2022", "2023", "2024"]
years      = ["2019", "2022", "2023", "2024"]

row_s1 = scope_df.loc[4, years_cols].astype(float)   # Scope 1
row_s2 = scope_df.loc[6, years_cols].astype(float)   # Scope 2 (location-based)
row_s3 = scope_df.loc[12, years_cols].astype(float)  # Scope 3

total_scope123 = row_s1 + row_s2 + row_s3
total_scope123.index = years

print(total_scope123)
# Out:
# 2019    9795210.0
# 2022    8052147.0
# 2023    7147327.0
# 2024    7334795.0
# dtype: float64

# %%
plt.figure()
plt.plot(total_scope123.index, total_scope123.values, marker="o", color="purple")
plt.xlabel("Year")
plt.ylabel("Total emissions (tonnes CO2e)")
plt.title("Total Scope 1+2+3 Emissions Trend")
plt.grid(True)
plt.show()
